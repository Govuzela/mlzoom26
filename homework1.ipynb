# %%
# importing  the required libaries
import os
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
filepath = "car_fuel_efficiency_2026.csv"

# %%
df = pd.read_csv(filepath)  
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.columns
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df[df['origin']=='Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
df.groupby('origin')['fuel_efficiency_mpg'].max()
# Out:
# origin
# Asia      41.2
# Europe    39.4
# USA       38.2
# Name: fuel_efficiency_mpg, dtype: float64

# %%
df['horsepower'].mean()
# Out:
# np.float64(254.44601556505535)

# %%
mode_hp = df['horsepower'].mode()[0]
mode_hp
# Out:
# np.float64(252.0)

# %%
df['horsepower'] = df['horsepower'].fillna(mode_hp)

# %%
df['horsepower'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower               0
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
# Check how many missing values are left (should be 0)
print("Missing values remaining:", df['horsepower'].isna().sum())
# Out:
# Missing values remaining: 0

# %%
df['horsepower'].isna().sum()
# Out:
# np.int64(0)

# %%
df['horsepower'].mean()
# Out:
# np.float64(254.2315)

# %%
X = df[['vehicle_weight','model_year']].iloc[:7].values
type(X)
# Out:
# numpy.ndarray

# %%
XTX = np.dot(X.T, X)
XTX
# Out:
# array([[127902500,  59738830],
#        [ 59738830,  27968386]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

XTX_inv =np.linalg.inv(XTX)

# %%
w = np.dot(XTX_inv,X.T).dot(y)
w
# Out:
# array([-0.2382193 ,  1.03784831])

# %%
w.sum()
# Out:
# np.float64(0.7996290105453119)
